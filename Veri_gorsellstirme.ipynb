# %% [markdown]
# # Veriye İlk Bakış

# %% [markdown]
# ### Verinin hikayesinin ve yapısının incelenmesi.

# %%
import seaborn as sns
planets = sns.load_dataset("planets") #planets isimli dataseti seaborn kütüphanesinden dahil edip inceleyeceğiz.
planets.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
#             method  number  orbital_period   mass  distance  year
# 0  Radial Velocity       1         269.300   7.10     77.40  2006
# 1  Radial Velocity       1         874.774   2.21     56.95  2008
# 2  Radial Velocity       1         763.000   2.60     19.84  2011
# 3  Radial Velocity       1         326.030  19.40    110.62  2007
# 4  Radial Velocity       1         516.220  10.50    119.47  2009

# %%
#veri setinin hikayesi nedir?  İlk bu sorgulanmalı.

# %%
df = planets.copy() # yapılamsı gereken ilk adımlardan biri verinin orjinalini kopyalamaktır.
#böylece orjinal hali korunmuş olur.

# %%
df.head()
# Out:
#             method  number  orbital_period   mass  distance  year
# 0  Radial Velocity       1         269.300   7.10     77.40  2006
# 1  Radial Velocity       1         874.774   2.21     56.95  2008
# 2  Radial Velocity       1         763.000   2.60     19.84  2011
# 3  Radial Velocity       1         326.030  19.40    110.62  2007
# 4  Radial Velocity       1         516.220  10.50    119.47  2009

# %%
df.tail()
# Out:
#        method  number  orbital_period  mass  distance  year
# 1030  Transit       1        3.941507   NaN     172.0  2006
# 1031  Transit       1        2.615864   NaN     148.0  2007
# 1032  Transit       1        3.191524   NaN     174.0  2007
# 1033  Transit       1        4.125083   NaN     293.0  2008
# 1034  Transit       1        4.187757   NaN     260.0  2008

# %%
# veriseti yapısal bilgileri incelenmeli

# %%
df.info() #yapısal bilgiler  # object demek kategorik değişken demek
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1035 entries, 0 to 1034
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   method          1035 non-null   object
#  1   number          1035 non-null   int64
#  2   orbital_period  992 non-null    float64
#  3   mass            513 non-null    float64
#  4   distance        808 non-null    float64
#  5   year            1035 non-null   int64
# dtypes: float64(3), int64(2), object(1)
# memory usage: 48.6+ KB

# %%
df.dtypes # değişken türlerini inceleyebiliyoruz.
# Out:
# method             object
# number              int64
# orbital_period    float64
# mass              float64
# distance          float64
# year                int64
# dtype: object

# %%
# object lerin kategorik olduğunu söylemiştik. program genlde zaten object'in kategorik değişken olduğunu anlıyor.
# Ancak bazı fonksiyonlar sıradan string muamelesi yapıyor ve bu da bazı istenmeyen sonuçlara neden olabiliyor.
# bu nedenle emin olduktan sonra objecti kategorik değişkene çevrilmelidir.

# %%
import pandas as pd # pandas kütüphanesi eklendi.
df.method = pd.Categorical(df.method) # pandas kütüphanesinden categorical adlı fonksiyona df.method çağırdım.
#df.methoda atadım böylece method category e döndü.

# %%
df.dtypes # görğüldüğü gibi object olan method, category e çevrildi.
# Out:
# method            category
# number               int64
# orbital_period     float64
# mass               float64
# distance           float64
# year                 int64
# dtype: object

# %%
df.head()
# Out:
#             method  number  orbital_period   mass  distance  year
# 0  Radial Velocity       1         269.300   7.10     77.40  2006
# 1  Radial Velocity       1         874.774   2.21     56.95  2008
# 2  Radial Velocity       1         763.000   2.60     19.84  2011
# 3  Radial Velocity       1         326.030  19.40    110.62  2007
# 4  Radial Velocity       1         516.220  10.50    119.47  2009

# %% [markdown]
# # Veri Setinin Betimlenmesi

# %%
import seaborn as sns
planets = sns.load_dataset("planets")
df = planets.copy()

# %%
df
# Out:
#                method  number  orbital_period   mass  distance  year
# 0     Radial Velocity       1      269.300000   7.10     77.40  2006
# 1     Radial Velocity       1      874.774000   2.21     56.95  2008
# 2     Radial Velocity       1      763.000000   2.60     19.84  2011
# 3     Radial Velocity       1      326.030000  19.40    110.62  2007
# 4     Radial Velocity       1      516.220000  10.50    119.47  2009
# ...               ...     ...             ...    ...       ...   ...
# 1030          Transit       1        3.941507    NaN    172.00  2006
# 1031          Transit       1        2.615864    NaN    148.00  2007
# 1032          Transit       1        3.191524    NaN    174.00  2007
# 1033          Transit       1        4.125083    NaN    293.00  2008
# 1034          Transit       1        4.187757    NaN    260.00  2008
#
# [1035 rows x 6 columns]

# %%
df.head()
# Out:
#             method  number  orbital_period   mass  distance  year
# 0  Radial Velocity       1         269.300   7.10     77.40  2006
# 1  Radial Velocity       1         874.774   2.21     56.95  2008
# 2  Radial Velocity       1         763.000   2.60     19.84  2011
# 3  Radial Velocity       1         326.030  19.40    110.62  2007
# 4  Radial Velocity       1         516.220  10.50    119.47  2009

# %%
df.shape
# Out:
# (1035, 6)

# %%
df.columns
# Out:
# Index(['method', 'number', 'orbital_period', 'mass', 'distance', 'year'], dtype='object')

# %%
import pandas as pd

df.method = pd.Categorical(df.method)

# %%
df.dtypes
# Out:
# method            category
# number               int64
# orbital_period     float64
# mass               float64
# distance           float64
# year                 int64
# dtype: object

# %%
df.describe().T #Eksik gözlemleri göz ardı ederek istatistik çıkarır ve kategorik değişkenleri çıkarır.
# T görünümünü değiştirir.
# Out:
#                  count         mean  ...       75%       max
# number          1035.0     1.785507  ...     2.000       7.0
# orbital_period   992.0  2002.917596  ...   526.005  730000.0
# mass             513.0     2.638161  ...     3.040      25.0
# distance         808.0   264.069282  ...   178.500    8500.0
# year            1035.0  2009.070531  ...  2012.000    2014.0
#
# [5 rows x 8 columns]

# %%
# describe fonnksyonun yukardaki özelliğinde bir şeye dikkat etmek gerekir.
# kategorik değişken her zaman object olmaz da öyle olur ki sayısal değişken kategorik olur(erkek-1/kız-0 gibi).
# eğer durum böyleyse elde edeceğimz istatistik yanıltıcı olabilir.
# bu durumda öncelikle verinin hikayesinden yola çıkarak mantığa uygun bir  şekilde betimlenmelidir.
# bu adım veri görselleştirme ve makine öğrenmesinden önce yapılması gereken şeylerden önemli bir tanesidir.

# %%
df.describe().T
#veriyi yorumlayalım

# galaksilerdeki gezegen  sayısını veren number değişkenin ortalaması düşük,standartsapması düşük min 1 max 7
# bakılacak olursa çok da etkili bir değişken değil

# mass'e bakıyorum. gezegen sayısının az olduğu bu sette min 0.003 max 25 birim kütle farkı olması ve std nın ortallamadan yüksek olması
# kütlenin biraz aha dengesiz büyüklüklerde dağıldığını gsteriyor gibi.

# min ve max arasndaki fark distance nin çok yayılımlı olduğunu gösteriyor..
# Out:
#                  count         mean           std          min         25%  \
# number          1035.0     1.785507      1.240976     1.000000     1.00000
# orbital_period   992.0  2002.917596  26014.728304     0.090706     5.44254
# mass             513.0     2.638161      3.818617     0.003600     0.22900
# distance         808.0   264.069282    733.116493     1.350000    32.56000
# year            1035.0  2009.070531      3.972567  1989.000000  2007.00000
#
#                       50%       75%       max
# number             1.0000     2.000       7.0
# orbital_period    39.9795   526.005  730000.0
# mass               1.2600     3.040      25.0
# distance          55.2500   178.500    8500.0
# year            2010.0000  2012.000    2014.0

# %%
df.describe(include = 'all').T # include all diyerek tüm değişkenleri ekleyebiliriz.
# ama bu bu örnek bazında pek mantıklı olmayacaktır. kategorik değişkenlerde çok nan(eksik değer) veriyor mesela
# Out:
#                count unique              top  ...      50%      75%     max
# method          1035     10  Radial Velocity  ...      NaN      NaN     NaN
# number          1035    NaN              NaN  ...        1        2       7
# orbital_period   992    NaN              NaN  ...  39.9795  526.005  730000
# mass             513    NaN              NaN  ...     1.26     3.04      25
# distance         808    NaN              NaN  ...    55.25    178.5    8500
# year            1035    NaN              NaN  ...     2010     2012    2014
#
# [6 rows x 11 columns]

# %% [markdown]
# ### Eksik değerlerin incelenmesi

# %%
import seaborn as sns
planets = sns.load_dataset("planets")
df = planets.copy()
df.head()
# Out:
#             method  number  orbital_period   mass  distance  year
# 0  Radial Velocity       1         269.300   7.10     77.40  2006
# 1  Radial Velocity       1         874.774   2.21     56.95  2008
# 2  Radial Velocity       1         763.000   2.60     19.84  2011
# 3  Radial Velocity       1         326.030  19.40    110.62  2007
# 4  Radial Velocity       1         516.220  10.50    119.47  2009

# %%
# hiç eksik gözlem(değer) var mı?
df.isnull().values.any()
# Out:
# True

# %%
# hangi değişkende kaçar tane eksik gözlem var?
df.isnull().sum()
# Out:
# method              0
# number              0
# orbital_period     43
# mass              522
# distance          227
# year                0
# dtype: int64

# %%
df["distance"].fillna(0, inplace = True ) 
# burda değişken ismini belirtip fillna() dediğimizde () içine yazdıklarımızı o değişkendeki nan lere atıyor.

# %%
df.isnull().sum()
# Out:
# method              0
# number              0
# orbital_period     43
# mass              522
# distance            0
# year                0
# dtype: int64

# %%
# eksik gözlem çok hassas konulardır aykırı gözlem vs.farklı yöntemleri var.

# %%
df["orbital_period"].fillna(df.orbital_period.mean(),inplace = True)
 # değişkenin nan'lerini o değişkenin ortalamasıyla değiştirdik.

# %%
df.isnull().sum()
# Out:
# method              0
# number              0
# orbital_period      0
# mass              522
# distance            0
# year                0
# dtype: int64

# %%
df = planets.copy() # verinin yapısı bozuldu tekrar başa alalım.

# %%
df.head()
# Out:
#             method  number  orbital_period   mass  distance  year
# 0  Radial Velocity       1         269.300   7.10     77.40  2006
# 1  Radial Velocity       1         874.774   2.21     56.95  2008
# 2  Radial Velocity       1         763.000   2.60     19.84  2011
# 3  Radial Velocity       1         326.030  19.40    110.62  2007
# 4  Radial Velocity       1         516.220  10.50    119.47  2009

# %% [markdown]
# ## Kategorik değişkenler ve Özetleri

# %%
import pandas as pd
df.method = pd.Categorical(df.method)
df.dtypes
# df.method'u kategorik değişkene çevirdim.
# Out:
# method            category
# number               int64
# orbital_period     float64
# mass               float64
# distance           float64
# year                 int64
# dtype: object

# %%
kat_df = df.select_dtypes(include = "category") # dataset'den sadece  bir değişken türünü seçtim

# %%
kat_df.head()
# Out:
#             method
# 0  Radial Velocity
# 1  Radial Velocity
# 2  Radial Velocity
# 3  Radial Velocity
# 4  Radial Velocity

# %% [markdown]
# ### Kategorik Değişkenlerin Sınıflarına ve Sınıf Sayısına Erişmek

# %%
kat_df.method.unique() #kat_df'de df'i methodlar değişeknine böldüm. burda da onun methodlarını tek tek aldım.
# Out:
# [Radial Velocity, Imaging, Eclipse Timing Variations, Transit, Astrometry, Transit Timing Variations, Orbital Brightness Modulation, Microlensing, Pulsar Timing, Pulsation Timing Variations]
# Categories (10, object): [Radial Velocity, Imaging, Eclipse Timing Variations, Transit, ...,
#                           Orbital Brightness Modulation, Microlensing, Pulsar Timing, Pulsation Timing Variations]

# %%
kat_df["method"].value_counts() # methodumunn hangi sınıfından kaç tane olduğunu buldum. Bu fraekans bilgisi.
# Out:
# Radial Velocity                  553
# Transit                          397
# Imaging                           38
# Microlensing                      23
# Eclipse Timing Variations          9
# Pulsar Timing                      5
# Transit Timing Variations          4
# Orbital Brightness Modulation      3
# Astrometry                         2
# Pulsation Timing Variations        1
# Name: method, dtype: int64

# %%
kat_df["method"].value_counts().count() #onu da count ettim. Sınıf sayısına eriştim
# Out:
# 10

# %%
df["method"].value_counts().plot.barh(); # plot().barh ifadesiyle elimizdeki sınıf frekans bilgisini grafiğe çeviridik

# %%
df_num = df.select_dtypes(include = ["float64","int64"]) # sürekli değişeknlere eriştik.
df_num
# Out:
#       number  orbital_period   mass  distance  year
# 0          1      269.300000   7.10     77.40  2006
# 1          1      874.774000   2.21     56.95  2008
# 2          1      763.000000   2.60     19.84  2011
# 3          1      326.030000  19.40    110.62  2007
# 4          1      516.220000  10.50    119.47  2009
# ...      ...             ...    ...       ...   ...
# 1030       1        3.941507    NaN    172.00  2006
# 1031       1        2.615864    NaN    148.00  2007
# 1032       1        3.191524    NaN    174.00  2007
# 1033       1        4.125083    NaN    293.00  2008
# 1034       1        4.187757    NaN    260.00  2008
#
# [1035 rows x 5 columns]

# %%
df_num.describe().T
# Out:
#                  count         mean  ...       75%       max
# number          1035.0     1.785507  ...     2.000       7.0
# orbital_period   992.0  2002.917596  ...   526.005  730000.0
# mass             513.0     2.638161  ...     3.040      25.0
# distance         808.0   264.069282  ...   178.500    8500.0
# year            1035.0  2009.070531  ...  2012.000    2014.0
#
# [5 rows x 8 columns]

# %%
df["distance"].describe().T #df deki her hangi bir değişken özelinde istatistiksel bilgilere erişebiliriz.
# Out:
# count     808.000000
# mean      264.069282
# std       733.116493
# min         1.350000
# 25%        32.560000
# 50%        55.250000
# 75%       178.500000
# max      8500.000000
# Name: distance, dtype: float64

# %%
df["distance"].mean() #vb işlemlerle değişken özelinde bir istatistiksel fonksiyonu kullandık.
# Out:
# 264.06928217821786

# %%
kat_df = df.select_dtypes(include = "category")

# %%
kat_df["method"].value_counts().count()
# Out:
# 10

# %%
kat_df["method"].value_counts()
# Out:
# Radial Velocity                  553
# Transit                          397
# Imaging                           38
# Microlensing                      23
# Eclipse Timing Variations          9
# Pulsar Timing                      5
# Transit Timing Variations          4
# Orbital Brightness Modulation      3
# Astrometry                         2
# Pulsation Timing Variations        1
# Name: method, dtype: int64

# %%
kat_df.method.unique()
# Out:
# [Radial Velocity, Imaging, Eclipse Timing Variations, Transit, Astrometry, Transit Timing Variations, Orbital Brightness Modulation, Microlensing, Pulsar Timing, Pulsation Timing Variations]
# Categories (10, object): [Radial Velocity, Imaging, Eclipse Timing Variations, Transit, ...,
#                           Orbital Brightness Modulation, Microlensing, Pulsar Timing, Pulsation Timing Variations]

# %% [markdown]
# # Dağılım grafikleri

# %% [markdown]
# ## Barlplot

# %%
#Sutun grafikleri içindir. 
#Sutun grafikleri elimizdeki kategorik değişkenleri sınıflandırmak için kullanılır. Önemli.

# %%
import seaborn as sns
diamonds = sns.load_dataset("diamonds")
df = diamonds.copy()
df.head()

#price: fiyat
#carat: ağırlık
#cut:: kalite 
#color: renk (J(worst) to D(best))
#clarity:temizliği(I1(worst),IF (best))
#x(lenght)
#y(width)
#z(depth)

#depth:toplam derinlik yüzdesi
#table: elmasın en geniş noktasına göre genişliği
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %% [markdown]
# #### Veri Setine İlk Bakış

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53940 non-null  float64
#  1   cut      53940 non-null  object
#  2   color    53940 non-null  object
#  3   clarity  53940 non-null  object
#  4   depth    53940 non-null  float64
#  5   table    53940 non-null  float64
#  6   price    53940 non-null  int64
#  7   x        53940 non-null  float64
#  8   y        53940 non-null  float64
#  9   z        53940 non-null  float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 4.1+ MB

# %%
df.tail()
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64

# %%
df.describe().T
# Out:
#          count         mean          std    min     25%      50%      75%  \
# carat  53940.0     0.797940     0.474011    0.2    0.40     0.70     1.04
# depth  53940.0    61.749405     1.432621   43.0   61.00    61.80    62.50
# table  53940.0    57.457184     2.234491   43.0   56.00    57.00    59.00
# price  53940.0  3932.799722  3989.439738  326.0  950.00  2401.00  5324.25
# x      53940.0     5.731157     1.121761    0.0    4.71     5.70     6.54
# y      53940.0     5.734526     1.142135    0.0    4.72     5.71     6.54
# z      53940.0     3.538734     0.705699    0.0    2.91     3.53     4.04
#
#             max
# carat      5.01
# depth     79.00
# table     95.00
# price  18823.00
# x         10.74
# y         58.90
# z         31.80

# %%
df["cut"].value_counts()
# Out:
# Ideal        21551
# Premium      13791
# Very Good    12082
# Good          4906
# Fair          1610
# Name: cut, dtype: int64

# %%
df["color"].value_counts()
# Out:
# G    11292
# E     9797
# F     9542
# H     8304
# D     6775
# I     5422
# J     2808
# Name: color, dtype: int64

# %%
#ordinal tanımlama. Bu datasetin içindeki kategorik değişkenler ordinal çünkü aralarında iyiden kötüye fark var.
from pandas.api.types import CategoricalDtype

# %%
df.cut.head()
# Out:
# 0      Ideal
# 1    Premium
# 2       Good
# 3    Premium
# 4       Good
# Name: cut, dtype: object

# %%
df.cut = df.cut.astype(CategoricalDtype(ordered = True)) #df.cut ı astype ile categoricalDtype'a ordinal bir şekilde dönüştürdük.

# %%
df.dtypes
# Out:
# carat       float64
# cut        category
# color        object
# clarity      object
# depth       float64
# table       float64
# price         int64
# x           float64
# y           float64
# z           float64
# dtype: object

# %%
df.cut.head(1) #sıralama verisetinin hikayesine göre değil çok dikkatttt
# Out:
# 0    Ideal
# Name: cut, dtype: category
# Categories (5, object): [Fair < Good < Ideal < Premium < Very Good]

# %%
cut_kategoriler = ["Fair","Good","Very Good","Premium","Ideal"] #bunun için uygun sıralamayı barındıran bi dizi  oluşturdum.

# %%
df.cut = df.cut.astype(CategoricalDtype(categories = cut_kategoriler, ordered = True))

# %%
df.cut.head() #böyle bir sorgulma yapma sebebim ordinal bir kategorik değişkenin sıralamasının önemli olmasıdır.
# Out:
# 0      Ideal
# 1    Premium
# 2       Good
# 3    Premium
# 4       Good
# Name: cut, dtype: category
# Categories (5, object): [Fair < Good < Very Good < Premium < Ideal]

# %%
# haydi bunu birde diğer ordinal object olan color değişkenie uyuglayalım.

# %%
df.color = df.color.astype(CategoricalDtype(ordered = True)) # kategorik olarak sırala dedik

# %%
df.color.head() #sıraya baktık ancak sıra uygun değil
# Out:
# 0    E
# 1    E
# 2    E
# 3    I
# 4    J
# Name: color, dtype: category
# Categories (7, object): [D < E < F < G < H < I < J]

# %%
color_kategoriler = ["J","I","H","G","F","E","D"] # kendi değişkenimize uygun sıırayı yazdık.

# %%
df.color = df.color.astype(CategoricalDtype(categories = color_kategoriler, ordered = True))# categories argümanını açıp içine kndi değişkenimizi yazdık

# %%
df.color.head() # böylece uygun sıralanmış oldu.
# Out:
# 0    E
# 1    E
# 2    E
# 3    I
# 4    J
# Name: color, dtype: category
# Categories (7, object): [J < I < H < G < F < E < D]

# %%
df.dtypes
# Out:
# carat       float64
# cut        category
# color      category
# clarity      object
# depth       float64
# table       float64
# price         int64
# x           float64
# y           float64
# z           float64
# dtype: object

# %%
#bir de clarty üzerine sırlama işlemi yapalım

# %%
df.clarity = df.clarity.astype(CategoricalDtype(ordered = True))

# %%
df.clarity.head() #görüldüğü gibi sıralama hatalı
# Out:
# 0    SI2
# 1    SI1
# 2    VS1
# 3    VS2
# 4    SI2
# Name: clarity, dtype: category
# Categories (8, object): [I1 < IF < SI1 < SI2 < VS1 < VS2 < VVS1 < VVS2]

# %%
clarity_kategoriler = ["I1","SI1","VS2","VS1","VVS2","VVS1","IF"] #uygun sırayı kendim yazdım

# %%
df.clarity = df.clarity.astype(CategoricalDtype(categories = clarity_kategoriler, ordered =True)) #uygun sırayı yazdığım değişeknimi categories argümnına eşitlledim

# %%
df.clarity.head()  #sıralama başarılı
# Out:
# 0    NaN
# 1    SI1
# 2    VS1
# 3    VS2
# 4    NaN
# Name: clarity, dtype: category
# Categories (7, object): [I1 < SI1 < VS2 < VS1 < VVS2 < VVS1 < IF]

# %%
#barplot sutun grafiği oluşturma

# %%
#pendas kullanarak kategorik sınıf rekanslarından birrini görselleştirelim.

# %%
df["cut"].value_counts().plot.barh().set_title("Cut Değişkeninin Sınıf Frekansları");
 #grafiği oluşturduk ve set_title ile başlık koyduk

# %%
(df["cut"]                                                                                        
 .value_counts()                                     
 .plot.barh()
 .set_title("Cut Değişkeninin Sınıf Frekansları"));

# %%
import seaborn as sns

# %%
sns.barplot(x = "cut", y = df.cut.index, data = df) #sns den barplot fonksiyonu ile x eksenine cut değişkenini y ye ise cut index yani frekans bilgisi ekledik.
# data argümanına da df datasetimizi verdik..

# %% [markdown]
# ## Çaprazlamalar

# %%
import seaborn as sns
from pandas.api.types import CategoricalDtype
diamonds =sns.load_dataset("diamonds")
df = diamonds.copy()
cut_kategoriler = ["Fair","Good","Very Good","Premium","Ideal"]
df.cut = df.cut.astype(CategoricalDtype(categories = cut_kategoriler,ordered = True))
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
sns.catplot(x ='cut',y = 'price',data = df); # catplot fonksiyonun x ine cut y sine price değişkenlerini verdik. df tatasından
#catplot nokta yoğunluklarından oluşuyor.

# %%
# görüldüğü üzere yüksek fiyatlar yüksek kalitede daha yoğunken fair de az

# %%
sns.barplot(x = "cut",y ="price", hue = "color",data = df   ) #bar plot düz sütunlrdan oluşuyor

#burda price ekseninde 6000'e  kadar gitmiş . Bu değerler iki kategorik değişken bir arada bulunduğunda ki price değişkeninin or
dağılımıdır. 
#üzerlerindeki çubbuklar ise standart sapma değerleridir.

# %%
df.groupby(["cut","color"])["price"].mean()
# Out:
# cut        color
# Fair       D        4291.061350
#            E        3682.312500
#            F        3827.003205
#            G        4239.254777
#            H        5135.683168
#            I        4685.445714
#            J        4975.655462
# Good       D        3405.382175
#            E        3423.644159
#            F        3495.750275
#            G        4123.482204
#            H        4276.254986
#            I        5078.532567
#            J        4574.172638
# Very Good  D        3470.467284
#            E        3214.652083
#            F        3778.820240
#            G        3872.753806
#            H        4535.390351
#            I        5255.879568
#            J        5103.513274
# Premium    D        3631.292576
#            E        3538.914420
#            F        4324.890176
#            G        4500.742134
#            H        5216.706780
#            I        5946.180672
#            J        6294.591584
# ...

# %% [markdown]
# ## Histogram ve Yoğunluk Grafikleri

# %%
# histogram ve yoğunluk grafikleri sayısal dağılımın görselleştirilmesi açısındn özemli tekniklerdir.

# %%
sns.distplot(df.price,bins=100, kde = False); 
# distpllot fonksiyonuyla priceyi görselleştirdik. Yoğunluk grafiğini çalıştırak kde argümanını false yaptık.
# histogram değerleri belli değerlere böler ve bunların dağılımını görselleştirir.
# bins argümanıyla değerlerin bölünmelerini belirleyebiliyoruz.
# ancak bins değerleri önem arz ettiğinden ön tanımlı halde bırkmak önerilir.

# %%
# ?sns.distplot

# %%
sns.distplot(df.price, kde = True); 
#histogram ve yoğunluk dağlımını aynı anda kulandığımızda y eksenindeki değerler düşüyor v mantıksız bir grafik oluşacak.

# %%
sns.distplot(df.price,hist =False);
#histogramı çıkarmak istediğimizde hist fonksiyonunu false yapıyoruz

# %%
#grafiği analiz edersek bir çarpıklık var. Ortalama ile medyan biribirinden uzak ve standart sapma yüksek olbilir.

# %%
sns.kdeplot(df.price, shade =True) # kdeplot fonksiyonun shade argümanını true edersek yoğunluk grafiğinin altını doldurabiliriz.

# %% [markdown]
# ## Histogram ve Yoğunluk Çaprazlamaları

# %%
sns.kdeplot(df.price,shade =True);
# Burada y ekseni frekansların standartlaştırılmış hali. Biz burayla ilgilenmiyoruz y ile ilgileniyoruz.
#biz dağılımla ilgileniyoruz.
# grafikte 2 tane tepe var. Bu demek ki odaklanılan değeri ettkileyen birden fazla faktör var.

# %%
(sns
 .FacetGrid(df,
              hue ="cut", # cut boyutu ekledik.
              height=5, # grafiğin büyüklüğünü ayarladık.
              xlim = (0,10000)) # x eksekini limitlendirdik daha kolay okuyalım diye kısalttık.
.map(sns.kdeplot, "price",shade =True) # map in içinde kdeplot un shade ini true yaparak altı dolu grafik aldık.
.add_legend() # add_legend diyerek renklerin ne anlama geleceği biligisini progrmdan aldık.
)

# %%
(sns
 .FacetGrid(df,
              hue ="cut",
              height=5,
              xlim = (0,10000))
.map(sns.kdeplot, "price",shade =True)
)

# %%
sns.catplot(x = 'cut', y ="price", hue = "color",kind="point",data =df)

# Burada ideal üzerinden düşüneceek olursak color değişkenin kategorilerinin birbbirlerinden farklı seviyelerde bulunması 
# color değişkenin cutt değişkeniyle kesişiminde farklı bilgi taşınığı annlamına gelir. ayrıca yine ideal d pembeyle mavi aynı bilgiyi taşıyor.
# makine öğrenmesi agoritmalarının temel amacı genelde burdan örnek vverecek olursak bağımlı değişken olan price daki değişimleri cut veya color gibi
# farklı değişkenler arasındaki değişimlerinden bbilgi yakalamaya çalışmaktır.
# bunun içinse price ile diğer değişkenlerin arasında ayır edici bilgi taşınması ve bunun aranması oluyor. Bu çok önemli.
# y ekseninin 6000 e indirgenmiş olmasının sebebi aggregation yani toplulaştırma işlemleri.
# 2 groupby yaptığımızda bunların ortalamasıından çıkacak olan şey.

# %% [markdown]
# ## Boxplot

# %% [markdown]
# ### Veri Seti Hikayesi

# %% [markdown]
# ###### total_bill: yemeğin toplam fiyatı (vergi ve bahşiş dahil)
# ###### tip: bahşiş
# ###### sex: ücreti ödeyen kişinin cinsiyeti (0=male, 1=female)
# ###### smoker: grupta sigara içen var mı? (0=no, 1=yes)
# ###### day: gün(3=thur,4=fri,5=sat,6=sun)
# ###### time: ne zaman (0=day,1=night)
# ###### size: grupta kaç kişi var?

# %%
import seaborn as sns
tips = sns.load_dataset("tips")
df = tips.copy()
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.3 KB

# %%
df.describe().T
# Out:
#             count       mean       std   min      25%     50%      75%    max
# total_bill  244.0  19.785943  8.902412  3.07  13.3475  17.795  24.1275  50.81
# tip         244.0   2.998279  1.383638  1.00   2.0000   2.900   3.5625  10.00
# size        244.0   2.569672  0.951100  1.00   2.0000   2.000   3.0000   6.00

# %%
df["sex"].value_counts()
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64

# %%
df["smoker"].value_counts()
# Out:
# No     151
# Yes     93
# Name: smoker, dtype: int64

# %%
df["day"].value_counts()
# Out:
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: day, dtype: int64

# %%
df["time"].value_counts()
# Out:
# Dinner    176
# Lunch      68
# Name: time, dtype: int64

# %%
sns.boxplot(x = df["total_bill"]); #Kutu grafiği oluşturduk

# %%
sns.boxplot(x=df["total_bill"], orient = "v")

# %% [markdown]
# ## Çaprazlamalar

# %%
sns.boxplot(x = df["day"],y =df["total_bill"])
# hangi günler daha faza kazanılıyor. Görüyoruz.

# %%
# hangi günler daha fazla kazanıyoruz?

# %%
df.groupby("day")["total_bill"].mean() # burdan elde ettiğimiz verileri görselleştirelim
# Out:
# day
# Thur    17.682742
# Fri     17.151579
# Sat     20.441379
# Sun     21.410000
# Name: total_bill, dtype: float64

# %%
sns.boxplot(x = df["day"], y = df["total_bill"], data = df)

# %%
sns.boxplot(x= df["time"], y = df["total_bill"], data = df) # bu görsellerrde kutununn ortasındki çizgi medyanı verir

# %%
sns.boxplot(x = df["day"], y = df["total_bill"], hue = "sex",data = df);

# %% [markdown]
# #### Violin

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.catplot(y = "total_bill", kind = "violin",data = df); # cat_plot fonksiyonunda kind argümanına violin diyerek violin grafiği oluşturduk.

# %% [markdown]
# #### Violin Çaprazmaları

# %%
sns.catplot(x = "day", y = "total_bill", kind = "violin", data =df);

# %%
sns.catplot(x = "day", y ="total_bill", hue = "sex", kind ="violin", data = df); #cinsiyet kırılımın da boyut ekleyerek baktık.

# %% [markdown]
# ## Korelasyon Grafikleri
#
#
# ### Scatterplot

# %%
sns.scatterplot(x = "total_bill", y= "tip",data = df)

#burda total_bill arttıkça ödenen bhşiş miktarının arttığını söyleyebiliriz.
#iki sayısal değişken arasında ki yapılan incelemeye korelasyon denir.

# %% [markdown]
# ### Korelasyon Çaprazlamaları

# %%
sns.scatterplot(x = "total_bill", y ="tip", hue = "time",data = df)

# %%
sns.scatterplot(x ="total_bill", y="tip", hue ="time",style="time" ,data = df) #style la biçimlendirebiliriz.

# %%
sns.scatterplot(x = "total_bill", y = "tip", hue ="day", style ="time", data = df)
#time yani öğünün şeklini değiştirdim ve farklı renklerle day üzerinden inceledim. x ve y zaten belli

# %% [markdown]
# ## Doğrusal İlişkinin Gösterilmesi

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.lmplot(x = "total_bill", y = "tip", data = df)

# %%
sns.lmplot(x = "total_bill", y ="tip", hue = "smoker",data =df)

# %%
sns.lmplot(x = "total_bill", y = "tip", hue = "smoker", col = "time", data = df) #col için verilecek ayrık değişken, her bir durumu için grafik oluşturur.

# %%
sns.lmplot(x = "total_bill", y ="tip", hue ="smoker",col = "time",row ="sex",data = df) # col ile bölünen her bir değişkene kendi değerlerini deneterek 
#her birine grafik oluşturur.

# %% [markdown]
# ## Scatterplot Matrisi

# %%
import seaborn as sns
iris =sns.load_dataset("iris")
df = iris.copy()
df.head()
#çiçek türleri ve özellikleri ile alakalı teknik bir veri seti.
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.dtypes # türler nominal değişken o yüzden kategoriye çevirmeye gerek yok
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
df.shape # 150 gözlem 5 değişken
# Out:
# (150, 5)

# %%
sns.pairplot(df);
# df deki değişkenler arasındaki ilişkiler
# scatterplot görsellerinde değişkenler arasındaki saçılım ilişkisi toz bulutu halindeyse ya da yapısal forma sahip değil ya da 
# bu iki değişken arasında bir ilişki yoktur.
# eğer farklı bölgelere kümeleniyorsa yeni bir boyut eklenerek diğer değişkenlerle ilişkisi incelenmelidir.

# %%
sns.pairplot(df, hue = "species");
#kümelenmelerin sebebinin başka bir değişken olduğu görülmektedir.

# %%
sns.pairplot(df, hue ="species", markers = ["o","s","D"])

# %%
sns.pairplot(df, kind ="reg");

# %%
sns.pairplot(df, hue ="species", kind ="reg")
#boyutlandırılmış scatterplot matrisinde doğrusal korelasyonu ifade  ediyor.

# %% [markdown]
# ## Heatmap

# %%
import seaborn as sns 
flights = sns.load_dataset("flights")
df = flights.copy()
df.head()
# yıllara ve aylara göre uçak kullanan yolcu sayısını ifade eden bir veri seti.
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %%
df.shape
# Out:
# (144, 3)

# %%
df.info
# Out:
# <bound method DataFrame.info of      year      month  passengers
# 0    1949    January         112
# 1    1949   February         118
# 2    1949      March         132
# 3    1949      April         129
# 4    1949        May         121
# ..    ...        ...         ...
# 139  1960     August         606
# 140  1960  September         508
# 141  1960    October         461
# 142  1960   November         390
# 143  1960   December         432
#
# [144 rows x 3 columns]>

# %%
df["passengers"].describe()
# Out:
# count    144.000000
# mean     280.298611
# std      119.966317
# min      104.000000
# 25%      180.000000
# 50%      265.500000
# 75%      360.500000
# max      622.000000
# Name: passengers, dtype: float64

# %%
sns.heatmap(df) # df'i olduğu gibi heatmap'e veremeyiz çünkü bunu pivot table halinde vermemiz gerekiyor.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-129-1703a24e1414> in <module>()
# ----> 1 sns.heatmap(df) # df'i olduğu gibi heatmap'e veremeyiz çünkü bunu pivot table halinde vermemiz gerekiyor.
#
# /usr/local/lib/python3.6/dist-packages/seaborn/matrix.py in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     535     plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
#     536                           annot_kws, cbar, cbar_kws, xticklabels,
# --> 537                           yticklabels, mask)
#     538
#     539     # Add the pcolormesh kwargs here
#
# ...

# %%
df = df.pivot("month" ,"year","passengers"); #df'i pivot a çevirdik

# %%
df
# Out:
# year       1949  1950  1951  1952  1953  ...  1956  1957  1958  1959  1960
# month                                    ...
# January     112   115   145   171   196  ...   284   315   340   360   417
# February    118   126   150   180   196  ...   277   301   318   342   391
# March       132   141   178   193   236  ...   317   356   362   406   419
# April       129   135   163   181   235  ...   313   348   348   396   461
# May         121   125   172   183   229  ...   318   355   363   420   472
# June        135   149   178   218   243  ...   374   422   435   472   535
# July        148   170   199   230   264  ...   413   465   491   548   622
# August      148   170   199   242   272  ...   405   467   505   559   606
# September   136   158   184   209   237  ...   355   404   404   463   508
# October     119   133   162   191   211  ...   306   347   359   407   461
# November    104   114   146   172   180  ...   271   305   310   362   390
# ...

# %%
sns.heatmap(df);
# elimizde yapı saptama problemleri olduğunda çok işmize yarayan bir tekniktir.
# burda yıllar ilerledikçe uçuş tendinin arttığı çıkarılabilir.
# en çok tercih edilen yların yaz ayları olduğuna ulaşılabilir.

# %%
sns.heatmap(df, annot =True,fmt ="d")
# hücrelerin içerisine değerlerini yazdırdıık.(annot = true diyerek). fmt = d diyerek sınırlar çekerek düzenledim.

# %% [markdown]
# ## Çizgi Grafiği

# %% [markdown]
# ### Veri Seti hikayesi

# %%
import seaborn as sns
fmri = sns.load_dataset("fmri")
df = fmri.copy()
df.head()
#subject: verilerin toplandığı kişiler
#timepoint : zaman noktaları
#event : olay
#region:sinyalin alındığı bölge
df.tail()
# Out:
#      subject  timepoint event    region    signal
# 1059      s0          8   cue   frontal  0.018165
# 1060     s13          7   cue   frontal -0.029130
# 1061     s12          7   cue   frontal -0.004939
# 1062     s11          7   cue   frontal -0.025367
# 1063      s0          0   cue  parietal -0.006899

# %%
df.shape
# Out:
# (1064, 5)

# %%
df.info
# Out:
# <bound method DataFrame.info of      subject  timepoint event    region    signal
# 0        s13         18  stim  parietal -0.017552
# 1         s5         14  stim  parietal -0.080883
# 2        s12         18  stim  parietal -0.081033
# 3        s11         18  stim  parietal -0.046134
# 4        s10         18  stim  parietal -0.037970
# ...      ...        ...   ...       ...       ...
# 1059      s0          8   cue   frontal  0.018165
# 1060     s13          7   cue   frontal -0.029130
# 1061     s12          7   cue   frontal -0.004939
# 1062     s11          7   cue   frontal -0.025367
# 1063      s0          0   cue  parietal -0.006899
#
# [1064 rows x 5 columns]>

# %%
df.dtypes
# Out:
# subject       object
# timepoint      int64
# event         object
# region        object
# signal       float64
# dtype: object

# %%
df["timepoint"].describe()
# 0 ile 18 arası bir değişim söz konusu.
# ortalama ya da standart sapmanın çok bir önemi yok
# Out:
# count    1064.000000
# mean        9.000000
# std         5.479801
# min         0.000000
# 25%         4.000000
# 50%         9.000000
# 75%        14.000000
# max        18.000000
# Name: timepoint, dtype: float64

# %%
df["signal"].describe()
# Out:
# count    1064.000000
# mean        0.003540
# std         0.093930
# min        -0.255486
# 25%        -0.046070
# 50%        -0.013653
# 75%         0.024293
# max         0.564985
# Name: signal, dtype: float64

# %%
df.groupby("timepoint")["signal"].count()
#burdan her bir zaman noktsında eşit sayıda eşit sayma yapılmış.
# Out:
# timepoint
# 0     56
# 1     56
# 2     56
# 3     56
# 4     56
# 5     56
# 6     56
# 7     56
# 8     56
# 9     56
# 10    56
# 11    56
# 12    56
# 13    56
# 14    56
# 15    56
# 16    56
# 17    56
# 18    56
# Name: signal, dtype: int64

# %%
df.groupby("signal").count()
# Out:
#            subject  timepoint  event  region
# signal
# -0.255486        1          1      1       1
# -0.238474        1          1      1       1
# -0.224351        1          1      1       1
# -0.181241        1          1      1       1
# -0.178510        1          1      1       1
# ...            ...        ...    ...     ...
#  0.455575        1          1      1       1
#  0.460896        1          1      1       1
#  0.476055        1          1      1       1
#  0.494787        1          1      1       1
#  0.564985        1          1      1       1
#
# [1064 rows x 4 columns]

# %%
df.groupby("timepoint")["signal"].describe()
# Out:
#            count      mean       std  ...       50%       75%       max
# timepoint                             ...
# 0           56.0 -0.016662  0.028326  ... -0.018382  0.003539  0.074399
# 1           56.0 -0.025002  0.030641  ... -0.024533 -0.005388  0.063558
# 2           56.0 -0.012873  0.035440  ... -0.013183  0.009318  0.077277
# 3           56.0  0.034446  0.058260  ...  0.028430  0.061840  0.185581
# 4           56.0  0.098194  0.092838  ...  0.070166  0.144911  0.346775
# 5           56.0  0.137725  0.123353  ...  0.096535  0.211638  0.476055
# 6           56.0  0.127515  0.137332  ...  0.068850  0.218919  0.564985
# 7           56.0  0.075660  0.129704  ...  0.032486  0.144781  0.494787
# 8           56.0  0.013420  0.104216  ... -0.012834  0.030396  0.337143
# 9           56.0 -0.032041  0.072728  ... -0.038496  0.008717  0.221716
# 10          56.0 -0.053685  0.053148  ... -0.052906 -0.015302  0.089231
# ...

# %%
sns.lmplot(x = "timepoint", y ="signal", hue = "event",data =df)

# %%
sns.barplot(x = "subject",y ="signal", hue = "event",data = df   )

# %%
sns.lineplot(x = "timepoint",y ="signal" ,data = df)

# %%
sns.lineplot(x = "timepoint", y="signal",hue = "event", data =df)

# %%
sns.lineplot(x = "timepoint", y = "signal", hue = "event", style ="event", data = df)

# %%
sns.lineplot(x = "timepoint", 
             y = "signal", hue = "event",
             style="event",
             markers = True,
             
             data=df)

# %%
sns.lineplot(x = "timepoint", y ="signal", hue = "event", style ="event",markers = True,dashes = False, data = df)

# %%
sns.lineplot(x = "timepoint", y = "signal", hue  ="region", style ="event", data = df)

# %% [markdown]
# ## Basit Zaman Serisi Grafiği

# %%
#!pip install pandas_datareader
import pandas_datareader as pr

# %%
df = pr.get_data_yahoo("AAPL",start = "2016-01-01",end = "2019-01-01") # burada pr içinden apple hisse  senedinin yazdığımız tarihler arasındki değişimi gösteren 
# bir data aldık

# %%
df.head()
df.tail()
# Out:
#                   High         Low  ...      Volume   Adj Close
# Date                                ...
# 2018-12-24  151.550003  146.589996  ...  37169200.0  143.924454
# 2018-12-26  157.229996  146.720001  ...  58582500.0  154.059814
# 2018-12-27  156.770004  150.070007  ...  53117100.0  153.059998
# 2018-12-28  158.520004  154.550003  ...  42291400.0  153.138428
# 2018-12-31  159.360001  156.479996  ...  35003500.0  154.618546
#
# [5 rows x 6 columns]

# %%
df.shape
# Out:
# (754, 6)

# %%
kapanis = df["Close"]

# %%
kapanis.plot()

# %%
kapanis.index #zaman önemli olduğu için bunun indexlerinin doğru sırada olması önmlidir.
# bunu kontrol etmeliyiz.
# Out:
# DatetimeIndex(['2016-01-04', '2016-01-05', '2016-01-06', '2016-01-07',
#                '2016-01-08', '2016-01-11', '2016-01-12', '2016-01-13',
#                '2016-01-14', '2016-01-15',
#                ...
#                '2018-12-17', '2018-12-18', '2018-12-19', '2018-12-20',
#                '2018-12-21', '2018-12-24', '2018-12-26', '2018-12-27',
#                '2018-12-28', '2018-12-31'],
#               dtype='datetime64[ns]', name='Date', length=754, freq=None)

# %%
kapanis.index = pd.DatetimeIndex(kapanis.index)

# %%
kapanis.head()
# Out:
# Date
# 2016-01-04    105.349998
# 2016-01-05    102.709999
# 2016-01-06    100.699997
# 2016-01-07     96.449997
# 2016-01-08     96.959999
# Name: Close, dtype: float64

# %%
kapanis.plot()
